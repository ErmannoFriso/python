# %% [markdown]
# # Writing Math in Jupiter

# %% [markdown]
# ## How To write latex in Jupiter

# %% [markdown]
# [Writing Math Equations in Jupyter Notebook: A Naive Introduction](https://medium.com/analytics-vidhya/writing-math-equations-in-jupyter-notebook-a-naive-introduction-a5ce87b9a214)

# %% [markdown]
# ## Latex language

# %% [markdown]
# - [LaTeX cheatsheet](https://quickref.me/latex)
# - [Short Math Guide for LATEX](https://tug.ctan.org/info/short-math-guide/short-math-guide.pdf)
# - [Wikibooks - LaTeX/Mathematics](https://en.wikibooks.org/wiki/LaTeX/Mathematics)

# %%
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j}$

# %% [markdown]
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j}$

# %% [markdown]
# ## Esempio

# %% [markdown]
# $𝛿𝜖=a_{4}m^{4}+a_{3}m^{3}+a_{2}m^{2}+a_{1}m+a_{0}$

# %% [markdown]
# $M_{T}=M_{I}\frac{1-\dfrac{\rho_{a}}{\rho_{p}}}{1-\dfrac{\rho_{a}}{\rho_{l}}}\approxeq M_{I}(1+\epsilon)$
#
# $\epsilon = 0.00106$

# %% [markdown]
# # Introduzione SymPy

# %% [markdown]
# [Official documentation](https://docs.sympy.org/latest/index.html)
# [Dynamics and control](https://dynamics-and-control.readthedocs.io/en/latest/0_Getting_Started/Notebook%20introduction.html)
# [Esempi vari](https://scipy-lectures.org/packages/sympy.html)

# %%
import sympy

# %%
sympy.init_printing()

# %%
x = sympy.Symbol('x')

# %%
x
# Out:
# x

# %%
polynomial = (2*x + 3)**4
polynomial.expand()
# Out:
#     4       3        2
# 16⋅x  + 96⋅x  + 216⋅x  + 216⋅x + 81

# %%
polynomial
# Out:
#          4
# (2⋅x + 3)

# %%
P, V, T, R, n = sympy.symbols('P V T R n', posivite=True)

# %%
ideal_gas_law = sympy.Eq(P*V, n*R*T)
ideal_gas_law
# Out:
# P⋅V = R⋅T⋅n

# %%
y=sympy.cos(x)*x**3

# %%
sympy.plotting.plot(y,(x,-7.5,7.5))
